# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
#the location of the data file
filepath = '/home/lamontano/Capstone2_PsycheNasaProject/Capstone2/Data/SPT140_Data.csv'
#import the data
data = pd.read_csv(filepath)

# %%
sns.regplot(x="Thrust (mN)", y="Power (kW)", data=data)
sns.despine();

# %%
X =data['Thrust (mN)'].values
#from sklearn.model_selection import train_test_split
Y = data['Power (kW)'].values

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
# Out:
# (6,) (6,)
# (3,) (3,)

# %%
print(model.score(X_test,Y_test))
# Out:
# 0.9977159601762808

# %%
sns.regplot(x="Thrust (mN)", y="Discharge Current (A)", data=data)
sns.despine();

# %%
X =data['Thrust (mN)'].values
#from sklearn.model_selection import train_test_split
Y = data['Discharge Current (A)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
# Out:
# (6,) (6,)
# (3,) (3,)

# %%
print(model.score(X_test,Y_test))
# Out:
# 0.99229629772935

# %%
sns.regplot(x="Thrust (mN)", y="Discharge Voltage (V)", data=data)
sns.despine();

# %%
X =data['Thrust (mN)'].values
#from sklearn.model_selection import train_test_split
Y = data['Discharge Voltage (V)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
# Out:
# (6,) (6,)
# (3,) (3,)

# %%
print(model.score(X_test,Y_test))
# Out:
# 0.9893140869995741

# %%
sns.regplot(x="Thrust (mN)", y="Total Flow Rate (mg/s)", data=data)
sns.despine();

# %%
X =data['Thrust (mN)'].values
#from sklearn.model_selection import train_test_split
Y = data['Total Flow Rate (mg/s)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
# Out:
# (6,) (6,)
# (3,) (3,)

# %%
print(model.score(X_test,Y_test))
# Out:
# 0.9996094733339367

# %%
sns.regplot(x="Thrust (mN)", y="Magnet Current (A)", data=data)
sns.despine();

# %%
X =data['Thrust (mN)'].values
#from sklearn.model_selection import train_test_split
Y = data['Magnet Current (A)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
# Out:
# (6,) (6,)
# (3,) (3,)

# %%
print(model.score(X_test,Y_test))
# Out:
# 0.9241586163107349

# %%
sns.regplot(x="Thrust (mN)", y="Cathode Flow Fraction (%)", data=data)
sns.despine();

# %%
X =data['Thrust (mN)'].values
#from sklearn.model_selection import train_test_split
Y = data['Cathode Flow Fraction (%)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)

X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# -0.9972375690607733

# %%
sns.regplot(x="Thrust (mN)", y="Keeper Current (A)", data=data)
sns.despine();

# %%
X =data['Thrust (mN)'].values
#from sklearn.model_selection import train_test_split
Y = data['Keeper Current (A)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)

X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# -0.11084297207210159

# %%
sns.regplot(x="Thrust (mN)", y="CTGV (V)", data=data)
sns.despine();

# %%
X =data['Thrust (mN)'].values
#from sklearn.model_selection import train_test_split
Y = data['CTGV (V)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)

X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.8749508521970889

# %%
sns.regplot(x="Thrust (mN)", y="Specific Impulse (sec)", data=data)
sns.despine();

# %%
X =data['Thrust (mN)'].values
#from sklearn.model_selection import train_test_split
Y = data['Specific Impulse (sec)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)

X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.190768605124238

# %%
sns.regplot(x="Thrust (mN)", y="Thruster Efficiency (%)", data=data)
sns.despine();

# %%
X =data['Thrust (mN)'].values
#from sklearn.model_selection import train_test_split
Y = data['Thruster Efficiency (%)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)

X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.4766341880412295

# %%
sns.regplot(x="Thrust (mN)", y="Pressure (Torr)", data=data)
sns.despine();

# %%
X =data['Thrust (mN)'].values
#from sklearn.model_selection import train_test_split
Y = data['Pressure (Torr)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)

X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.9930171273635908
