# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
#the location of the data file
filepath = '/home/lamontano/Capstone2_PsycheNasaProject/Capstone2/Data/SPT100_TeamIonData.csv'
#import the data
data = pd.read_csv(filepath)

# %%
sns.regplot(x="Thrust", y="Power (W)", data=data)
sns.despine();

# %%
X =data['Thrust'].values
#from sklearn.model_selection import train_test_split
Y = data['Power (W)'].values

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (44,) (44,)
# (22,) (22,)

# %%
'''
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)
'''
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)

# %%
print(model.score(X_test,Y_test))
# Out:
# 0.9334377489000096

# %%
X =data['Thrust'].values
#from sklearn.model_selection import train_test_split
Y = data['Cathode'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.7939002758521678

# %%
sns.regplot(x="Thrust", y="Cathode", data=data)
sns.despine();

# %%
X =data['Thrust'].values
#from sklearn.model_selection import train_test_split
Y = data['Specific impulse (s)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.6748678622226403

# %%
sns.regplot(x="Thrust", y="Specific impulse (s)", data=data)
sns.despine();

# %%
X =data['Thrust'].values
#from sklearn.model_selection import train_test_split
Y = data['Efficiency'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.6275738641237271

# %%
sns.regplot(x="Thrust", y="Efficiency", data=data)
sns.despine();

# %%
X =data['Thrust'].values
#from sklearn.model_selection import train_test_split
Y = data['Anode Flow (mg/s)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.5266253421507798

# %%
sns.regplot(x="Thrust", y="Anode Flow (mg/s)", data=data)
sns.despine();

# %%
X =data['Thrust'].values
#from sklearn.model_selection import train_test_split
Y = data['Current (A)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.5989970257112394

# %%
sns.regplot(x="Thrust", y="Current (A)", data=data)
sns.despine();

# %%
X =data['Power (W)'].values
#from sklearn.model_selection import train_test_split
Y = data['Current (A)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.6562264442347472

# %%
sns.regplot(x="Power (W)", y="Current (A)", data=data)
sns.despine();

# %%
X =data['Power (W)'].values
#from sklearn.model_selection import train_test_split
Y = data['Anode Flow (mg/s)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.43125115099085276

# %%
sns.regplot(x="Power (W)", y="Anode Flow (mg/s)", data=data)
sns.despine();

# %%
X =data['Power (W)'].values
#from sklearn.model_selection import train_test_split
Y = data['Efficiency'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.48770137995566487

# %%
sns.regplot(x="Power (W)", y="Efficiency", data=data)
sns.despine();

# %%
X =data['Power (W)'].values
#from sklearn.model_selection import train_test_split
Y = data['Specific impulse (s)'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.6397752041197338

# %%
sns.regplot(x="Power (W)", y="Specific impulse (s)", data=data)
sns.despine();

# %%
X =data['Power (W)'].values
#from sklearn.model_selection import train_test_split
Y = data['Cathode'].values
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)
print(model.score(X_test,Y_test))
# Out:
# 0.6111336383419974

# %%
sns.regplot(x="Power (W)", y="Cathode", data=data)
sns.despine();
