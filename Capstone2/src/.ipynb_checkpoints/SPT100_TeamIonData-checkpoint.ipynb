# %%
import numpy as np
import matplotlib.pyplot as plt  # To visualize
import pandas as pd  # To read data
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('/home/lamontano/Capstone2_PsycheNasaProject/Capstone2/Data/SPT100_TeamIonData.csv')  # load data set
#Drop index column
data.drop(data.columns[len(data.columns)-1], axis=1, inplace=True)
X = np.array(data.iloc[:, 1:11].values)
label = LabelEncoder()
data['Thrust'] = label.fit_transform(data['Thrust'])
#from sklearn.model_selection import train_test_split
Y = np.array(data.Thrust)
print(Y)
print(X.shape, Y.shape)
print(data.head)
# Out:
# [ 3 19 29 37 45 52 54 57 59 51 15 21 32 43 50 56 61 49 11 23 30 31 36 46
#  58 60 62 40 47 45 41 35 28 25 17 10  6 34 55 53 48 44 38 27 20 14  7 39
#  26 22 18 16 12  9  5  2  0 42 33 29 24 17 13  8  4  1]
# (66, 10) (66,)
# <bound method NDFrame.head of     Voltage (V)  Current (A)  Power (W)  Anode Flow (mg/s)  \
# 0           300         3.01        903               3.45
# 1           300         3.25        975               3.87
# 2           300         3.51       1050               4.17
# 3           299         3.75       1120               4.42
# 4           299         3.97       1190               4.66
# 5           299         4.25       1270               4.93
# 6           299         4.50       1350               5.18
# 7           299         4.75       1420               5.42
# 8           299         4.98       1490               5.64
# 9           301         4.27       1280               4.96
# 10          300         3.01        904               3.55
# 11          300         3.24        973               3.80
# 12          300         3.49       1050               4.08
# 13          300         3.75       1130               4.37
# 14          300         4.08       1220               4.70
# 15          300         4.50       1350               5.12
# 16          300         5.00       1500               5.62
# 17          300         4.08       1220               4.70
# 18          300         3.00        901               3.35
# 19          300         3.26        979               3.67
# 20          300         3.48       1050               3.91
# 21          301         3.77       1130               4.16
# 22          300         4.00       1200               4.38
# 23          300         4.24       1270               4.64
# 24          300         4.50       1350               5.00
# 25          300         4.75       1430               5.23
# 26          300         4.98       1490               5.45
# 27          300         3.72       1120               4.17
# 28          250         5.02       1260               5.55
# 29          250         4.74       1190               5.30
# ..          ...          ...        ...                ...
# 36          250         2.98        744               3.61
# 37          250         4.31       1080               4.93
# 38          250         4.95       1240               5.53
# 39          250         4.75       1190               5.35
# 40          250         4.49       1120               5.12
# 41          250         4.24       1060               4.87
# 42          250         4.07       1020               4.71
# 43          250         3.75        938               4.38
# 44          250         3.50        874               4.12
# 45          250         3.25        812               3.83
# 46          250         3.01        752               3.58
# 47          250         4.07       1020               4.71
# 48          201         4.99       1000               5.51
# 49          201         4.76        955               5.30
# 50          201         4.50        903               5.05
# 51          201         4.25        853               4.82
# 52          201         4.01        805               4.59
# 53          201         3.74        751               4.34
# 54          201         3.48        698               4.11
# 55          201         3.25        652               3.87
# 56          201         2.98        598               3.61
# 57          201         4.98        998               5.48
# 0                   1220       0.293                  0.0014
# 1                   1450       0.430                  0.0015
# 2                   1480       0.441                  0.0015
# 3                   1490       0.448                  0.0016
# 4                   1510       0.453                  0.0016
# 5                   1540       0.464                  0.0017
# 6                   1550       0.467                  0.0018
# 7                   1550       0.464                  0.0018
# 8                   1580       0.478                  0.0019
# 9                   1520       0.452                  0.0017
# 10                  1370       0.405                  0.0014
# 11                  1410       0.425                  0.0014
# 12                  1450       0.441                  0.0015
# 13                  1480       0.455                  0.0015
# 14                  1520       0.470                  0.0016
# 15                  1550       0.484                  0.0017
# 16                  1590       0.496                  0.0018
# 17                  1510       0.464                  0.0016
# 18                  1220       0.349                  0.0015
# 19                  1310       0.399                  0.0016
# 20                  1330       0.401                  0.0017
# 21                  1270       0.358                  0.0018
# 22                  1290       0.359                  0.0019
# 23                  1320       0.375                  0.0019
# 24                  1470       0.463                  0.0018
# 25                  1500       0.474                  0.0019
# 26                  1520       0.481                  0.0020
# 27                  1350       0.411                  0.0017
# 28                  1330       0.396                  0.0021
# 29                  1330       0.402                  0.0020
# ..                   ...         ...                     ...
# 36                  1250       0.392                  0.0015
# 37                  1320       0.406                  0.0019
# 38                  1410       0.468                  0.0020
# 39                  1400       0.462                  0.0019
# 40                  1380       0.460                  0.0019
# 41                  1370       0.457                  0.0018
# 42                  1350       0.446                  0.0018
# 43                  1330       0.441                  0.0017
# 44                  1300       0.431                  0.0016
# 45                  1280       0.420                  0.0015
# 46                  1250       0.408                  0.0015
# 47                  1350       0.449                  0.0018
# 48                  1100       0.337                  0.0022
# 49                  1100       0.341                  0.0022
# 50                  1120       0.355                  0.0021
# 51                  1120       0.362                  0.0019
# 52                  1110       0.360                  0.0019
# 53                  1120       0.368                  0.0018
# 54                  1100       0.364                  0.0017
# 55                  1070       0.351                  0.0016
# 56                  1050       0.345                  0.0015
# 57                  1200       0.416                  0.0021
# 58                  1190       0.415                  0.0020
# 59                  1180       0.412                  0.0020
# 60                  1170       0.408                  0.0019
# 61                  1150       0.407                  0.0018
# 62                  1140       0.403                  0.0018
# 63                  1120       0.393                  0.0017
# 64                  1200       0.384                  0.0016
# 65                  1070       0.371                  0.0015
#
# [66 rows x 11 columns]>

# %%
data.describe().transpose()
# Out:
#                         count         mean         std        min         25%  \
# Voltage (V)              66.0   257.787879   40.916995   201.0000   201.00000
# Current (A)              66.0     3.991061    0.629645     2.9800     3.49000
# Power (W)                66.0  1025.166667  232.190743   598.0000   858.25000
# Anode Flow (mg/s)        66.0     4.568788    0.638097     3.3500     4.08750
# Cathode Flow (mg/s)      66.0     0.470455    0.251399     0.2600     0.26000
# Cathode                  66.0     5.045606    0.658827     3.7100     4.57500
# Cathode Fraction         66.0     0.094227    0.049086     0.0450     0.05550
# Thrust                   66.0    30.969697   18.071626     0.0000    16.25000
# Specific impulse (s)     66.0  1321.818182  150.669369  1050.0000  1200.00000
# Efficiency               66.0     0.415485    0.043896     0.2930     0.39225
# Facility Pressure (Pa)   66.0     0.001748    0.000202     0.0014     0.00160
#
#                               50%         75%        max
# Voltage (V)              250.0000   300.00000   301.0000
# Current (A)                4.0050     4.50000     5.0200
# Power (W)               1010.0000  1190.00000  1500.0000
# Anode Flow (mg/s)          4.6400     5.08750     5.6400
# Cathode Flow (mg/s)        0.5000     0.50000     1.0000
# Cathode                    5.1900     5.56250     6.4800
# Cathode Fraction           0.0860     0.11000     0.2400
# Thrust                    30.5000    45.75000    62.0000
# Specific impulse (s)    1330.0000  1450.00000  1590.0000
# Efficiency                 0.4140     0.45275     0.4960
# Facility Pressure (Pa)     0.0018     0.00190     0.0022

# %%
data.shape
# Out:
# (66, 11)

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,  test_size = 0.33)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (44, 10) (44,)
# (22, 10) (22,)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

LR = LinearRegression()
model = LR.fit(X_train, Y_train)
y_predictions = LR.predict(X_test)

# %%
print(model.score(X_test,Y_test))
# Out:
# 0.9720733837654946

# %%
# Plot Linear Regression
plt.scatter(X_test, Y_test,  color='black')
plt.plot(X_test, y_predictions, color='green')

plt.xticks(())
plt.yticks(())
plt.xlabel('True Values')
plt.ylabel('Predictions')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-38833ebf00fd> in <module>
#       1 # Plot Linear Regression
# ----> 2 plt.scatter(X_test, Y_test,  color='black')
#       3 plt.plot(X_test, y_predictions, color='green')
#       4
#       5 plt.xticks(())
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2860         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2861         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2862         is not None else {}), **kwargs)
#    2863     sci(__ret)
#    2864     return __ret
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4180         y = np.ma.ravel(y)
#    4181         if x.size != y.size:
# -> 4182             raise ValueError("x and y must be the same size")
#    4183
#    4184         if s is None:
#
# ValueError: x and y must be the same size

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression(penalty = 'l2', C = 0.1, solver = 'lbfgs', max_iter = 100000)

score = cross_val_score(LR, X, Y, cv = 2)
print('Cross-validated scores: ', score)

LR = LR.fit(X_train, Y_train)
y_predict = LR.predict(X_test)
print("Logistic Regression score: ", LR.score(X_test, Y_test))
# Out:
# /home/lamontano/.local/lib/python3.5/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   % (min_groups, self.n_splits)), UserWarning)
# Cross-validated scores:  [0. 0.]
# Logistic Regression score:  0.0
