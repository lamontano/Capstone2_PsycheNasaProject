# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from sklearn.ensemble import IsolationForest

# %%
#the location of the data file
filepath = '/home/lamontano/Capstone2_PsycheNasaProject/Capstone2/Data/SPT100_TeamIonData.csv'
#import the data
data = pd.read_csv(filepath)
data['Voltage (V)'].describe()
# Out:
# count     66.000000
# mean     257.787879
# std       40.916995
# min      201.000000
# 25%      201.000000
# 50%      250.000000
# 75%      300.000000
# max      301.000000
# Name: Voltage (V), dtype: float64

# %%
plt.scatter(range(data.shape[0]), np.sort(data['Voltage (V)'].values))
plt.xlabel('index')
plt.ylabel('Voltage (V)')
plt.title("Voltage SPT-100 distribution")
sns.despine()

# %%
sns.distplot(data['Voltage (V)'])
plt.title("Distribution of Voltage SPT-100")
sns.despine()

# %%
print("Skewness: %f" % data['Voltage (V)'].skew())
print("Kurtosis: %f" % data['Voltage (V)'].kurt())
# Out:
# Skewness: -0.282590
# Kurtosis: -1.487893

# %%
data['Current (A)'].describe()
# Out:
# count    66.000000
# mean      3.991061
# std       0.629645
# min       2.980000
# 25%       3.490000
# 50%       4.005000
# 75%       4.500000
# max       5.020000
# Name: Current (A), dtype: float64

# %%
plt.scatter(range(data.shape[0]), np.sort(data['Current (A)'].values))
plt.xlabel('index')
plt.ylabel('Current (A)')
plt.title("Current SPT-100 distribution")
sns.despine()

# %%
sns.distplot(data['Current (A)'])
plt.title("Distribution of Current SPT-100")
sns.despine()

# %%
print("Skewness: %f" % data['Current (A)'].skew())
print("Kurtosis: %f" % data['Current (A)'].kurt())
# Out:
# Skewness: -0.008526
# Kurtosis: -1.130782

# %%
data['Power (W)'].describe()
# Out:
# count      66.000000
# mean     1025.166667
# std       232.190743
# min       598.000000
# 25%       858.250000
# 50%      1010.000000
# 75%      1190.000000
# max      1500.000000
# Name: Power (W), dtype: float64

# %%
plt.scatter(range(data.shape[0]), np.sort(data['Power (W)'].values))
plt.xlabel('index')
plt.ylabel('Power (W)')
plt.title("Power SPT-100 distribution")
sns.despine()

# %%
sns.distplot(data['Power (W)'])
plt.title("Distribution of Power SPT-100")
sns.despine()

# %%
print("Skewness: %f" % data['Power (W)'].skew())
print("Kurtosis: %f" % data['Power (W)'].kurt())
# Out:
# Skewness: 0.157621
# Kurtosis: -0.643068

# %%
data['Anode Flow (mg/s)'].describe()
# Out:
# count    66.000000
# mean      4.568788
# std       0.638097
# min       3.350000
# 25%       4.087500
# 50%       4.640000
# 75%       5.087500
# max       5.640000
# Name: Anode Flow (mg/s), dtype: float64

# %%
plt.scatter(range(data.shape[0]), np.sort(data['Anode Flow (mg/s)'].values))
plt.xlabel('index')
plt.ylabel('Anode Flow (mg/s)')
plt.title("Anode Flow SPT-100 distribution")
sns.despine()

# %%
sns.distplot(data['Anode Flow (mg/s)'])
plt.title("Distribution of Anode Flow SPT-100")
sns.despine()

# %%
print("Skewness: %f" % data['Anode Flow (mg/s)'].skew())
print("Kurtosis: %f" % data['Anode Flow (mg/s)'].kurt())
# Out:
# Skewness: -0.106975
# Kurtosis: -1.084637

# %%
data['Cathode Flow (mg/s)'].describe()
# Out:
# count    66.000000
# mean      0.470455
# std       0.251399
# min       0.260000
# 25%       0.260000
# 50%       0.500000
# 75%       0.500000
# max       1.000000
# Name: Cathode Flow (mg/s), dtype: float64

# %%
plt.scatter(range(data.shape[0]), np.sort(data['Cathode Flow (mg/s)'].values))
plt.xlabel('index')
plt.ylabel('Cathode Flow (mg/s)')
plt.title("Cathode Flow SPT-100 distribution")
sns.despine()

# %%
sns.distplot(data['Cathode Flow (mg/s)'])
plt.title("Distribution of Cathode Flow SPT-100")
sns.despine()

# %%
print("Skewness: %f" % data['Cathode Flow (mg/s)'].skew())
print("Kurtosis: %f" % data['Cathode Flow (mg/s)'].kurt())
# Out:
# Skewness: 1.214801
# Kurtosis: 0.416910

# %%
data['Cathode'].describe()
# Out:
# count    66.000000
# mean      5.045606
# std       0.658827
# min       3.710000
# 25%       4.575000
# 50%       5.190000
# 75%       5.562500
# max       6.480000
# Name: Cathode, dtype: float64

# %%
plt.scatter(range(data.shape[0]), np.sort(data['Cathode'].values))
plt.xlabel('index')
plt.ylabel('Cathode')
plt.title("Cathode SPT-100 distribution")
sns.despine()

# %%
sns.distplot(data['Cathode'])
plt.title("Distribution of Cathode SPT-100")
sns.despine()

# %%
print("Skewness: %f" % data['Cathode'].skew())
print("Kurtosis: %f" % data['Cathode'].kurt())
# Out:
# Skewness: -0.042582
# Kurtosis: -0.749151

# %%
data['Cathode Fraction'].describe()
# Out:
# count    66.000000
# mean      0.094227
# std       0.049086
# min       0.045000
# 25%       0.055500
# 50%       0.086000
# 75%       0.110000
# max       0.240000
# Name: Cathode Fraction, dtype: float64

# %%
plt.scatter(range(data.shape[0]), np.sort(data['Cathode Fraction'].values))
plt.xlabel('index')
plt.ylabel('Cathode Fraction')
plt.title("Cathode Fraction SPT-100 distribution")
sns.despine()

# %%
sns.distplot(data['Cathode Fraction'])
plt.title("Distribution of Cathode Fraction SPT-100")
sns.despine()

# %%
print("Skewness: %f" % data['Cathode Fraction'].skew())
print("Kurtosis: %f" % data['Cathode Fraction'].kurt())
# Out:
# Skewness: 1.313026
# Kurtosis: 1.045159

# %%
data['Thrust'].describe()
# Out:
# count    66.000000
# mean     65.722727
# std      13.459052
# min      40.000000
# 25%      56.275000
# 50%      64.650000
# 75%      73.475000
# max      96.500000
# Name: Thrust, dtype: float64

# %%
plt.scatter(range(data.shape[0]), np.sort(data['Thrust'].values))
plt.xlabel('index')
plt.ylabel('Thrust')
plt.title("Thrust SPT-100 distribution")
sns.despine()

# %%
sns.distplot(data['Thrust'])
plt.title("Distribution of Thrust SPT-100")
sns.despine()

# %%
print("Skewness: %f" % data['Thrust'].skew())
print("Kurtosis: %f" % data['Thrust'].kurt())
# Out:
# Skewness: 0.298483
# Kurtosis: -0.369584

# %%
data['Specific impulse (s)'].describe()
# Out:
# count      66.000000
# mean     1321.818182
# std       150.669369
# min      1050.000000
# 25%      1200.000000
# 50%      1330.000000
# 75%      1450.000000
# max      1590.000000
# Name: Specific impulse (s), dtype: float64

# %%
plt.scatter(range(data.shape[0]), np.sort(data['Specific impulse (s)'].values))
plt.xlabel('index')
plt.ylabel('Specific impulse (s)')
plt.title("Specific impulse (s) SPT-100 distribution")
sns.despine()

# %%
sns.distplot(data['Specific impulse (s)'])
plt.title("Specific Impulse (s) SPT-100")
sns.despine()

# %%
print("Skewness: %f" % data['Specific impulse (s)'].skew())
print("Kurtosis: %f" % data['Specific impulse (s)'].kurt())
# Out:
# Skewness: -0.029153
# Kurtosis: -1.023594

# %%
data['Efficiency'].describe()
# Out:
# count    66.000000
# mean      0.415485
# std       0.043896
# min       0.293000
# 25%       0.392250
# 50%       0.414000
# 75%       0.452750
# max       0.496000
# Name: Efficiency, dtype: float64

# %%
plt.scatter(range(data.shape[0]), np.sort(data['Efficiency'].values))
plt.xlabel('index')
plt.ylabel('Efficiency')
plt.title("Efficiency SPT-100 distribution")
sns.despine()

# %%
sns.distplot(data['Efficiency'])
plt.title("Efficiency SPT-100")
sns.despine()

# %%
print("Skewness: %f" % data['Efficiency'].skew())
print("Kurtosis: %f" % data['Efficiency'].kurt())
# Out:
# Skewness: -0.373943
# Kurtosis: -0.393444

# %%
data['Facility Pressure (Pa)'].describe()
# Out:
# count    66.000000
# mean      0.001748
# std       0.000202
# min       0.001400
# 25%       0.001600
# 50%       0.001800
# 75%       0.001900
# max       0.002200
# Name: Facility Pressure (Pa), dtype: float64

# %%
plt.scatter(range(data.shape[0]), np.sort(data['Facility Pressure (Pa)'].values))
plt.xlabel('index')
plt.ylabel('Facility Pressure (Pa)')
plt.title("Facility Pressure (Pa) SPT-100 distribution")
sns.despine()

# %%
sns.distplot(data['Facility Pressure (Pa)'])
plt.title("Facility Pressure (Pa) SPT-100")
sns.despine()

# %%
print("Skewness: %f" % data['Facility Pressure (Pa)'].skew())
print("Kurtosis: %f" % data['Facility Pressure (Pa)'].kurt())
# Out:
# Skewness: 0.208318
# Kurtosis: -0.642471

# %%
isolation_forest = IsolationForest(n_estimators=100)
isolation_forest.fit(data['Voltage (V)'].values.reshape(-1, 1))
xx = np.linspace(data['Voltage (V)'].min(), data['Voltage (V)'].max(), len(data)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score), 
                 where=outlier==-1, color='r', 
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Voltage (V)')
plt.show();

# %%
isolation_forest = IsolationForest(n_estimators=100)
isolation_forest.fit(data['Current (A)'].values.reshape(-1, 1))
xx = np.linspace(data['Current (A)'].min(), data['Current (A)'].max(), len(data)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score), 
                 where=outlier==-1, color='r', 
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Current (A)')
plt.show();

# %%
isolation_forest = IsolationForest(n_estimators=100)
isolation_forest.fit(data['Power (W)'].values.reshape(-1, 1))
xx = np.linspace(data['Power (W)'].min(), data['Power (W)'].max(), len(data)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score), 
                 where=outlier==-1, color='r', 
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Power (W)')
plt.show();

# %%
isolation_forest = IsolationForest(n_estimators=100)
isolation_forest.fit(data['Anode Flow (mg/s)'].values.reshape(-1, 1))
xx = np.linspace(data['Anode Flow (mg/s)'].min(), data['Anode Flow (mg/s)'].max(), len(data)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score), 
                 where=outlier==-1, color='r', 
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Anode Flow (mg/s)')
plt.show();

# %%
isolation_forest = IsolationForest(n_estimators=100)
isolation_forest.fit(data['Cathode Flow (mg/s)'].values.reshape(-1, 1))
xx = np.linspace(data['Cathode Flow (mg/s)'].min(), data['Cathode Flow (mg/s)'].max(), len(data)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score), 
                 where=outlier==-1, color='r', 
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Cathode Flow (mg/s)')
plt.show();

# %%
isolation_forest = IsolationForest(n_estimators=100)
isolation_forest.fit(data['Cathode'].values.reshape(-1, 1))
xx = np.linspace(data['Cathode'].min(), data['Cathode'].max(), len(data)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score), 
                 where=outlier==-1, color='r', 
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Cathode')
plt.show();

# %%
isolation_forest = IsolationForest(n_estimators=100)
isolation_forest.fit(data['Cathode Fraction'].values.reshape(-1, 1))
xx = np.linspace(data['Cathode Fraction'].min(), data['Cathode Fraction'].max(), len(data)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score), 
                 where=outlier==-1, color='r', 
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Cathode Fraction')
plt.show();

# %%
isolation_forest = IsolationForest(n_estimators=100)
isolation_forest.fit(data['Thrust'].values.reshape(-1, 1))
xx = np.linspace(data['Thrust'].min(), data['Thrust'].max(), len(data)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score), 
                 where=outlier==-1, color='r', 
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Thrust')
plt.show();

# %%
isolation_forest = IsolationForest(n_estimators=100)
isolation_forest.fit(data['Specific impulse (s)'].values.reshape(-1, 1))
xx = np.linspace(data['Specific impulse (s)'].min(), data['Specific impulse (s)'].max(), len(data)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score), 
                 where=outlier==-1, color='r', 
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Specific impulse (s)')
plt.show();

# %%
isolation_forest = IsolationForest(n_estimators=100)
isolation_forest.fit(data['Efficiency'].values.reshape(-1, 1))
xx = np.linspace(data['Efficiency'].min(), data['Efficiency'].max(), len(data)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score), 
                 where=outlier==-1, color='r', 
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Efficiency')
plt.show();

# %%
isolation_forest = IsolationForest(n_estimators=100)
isolation_forest.fit(data['Facility Pressure (Pa)'].values.reshape(-1, 1))
xx = np.linspace(data['Facility Pressure (Pa)'].min(), data['Facility Pressure (Pa)'].max(), len(data)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score), 
                 where=outlier==-1, color='r', 
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Facility Pressure (Pa)')
plt.show();

# %%
sns.regplot(x="Thrust", y="Power (W)", data=data)
sns.despine();

# %%
sns.regplot(x="Thrust", y="Facility Pressure (Pa)", data=data)
sns.despine();

# %%
sns.regplot(x="Thrust", y="Voltage (V)", data=data)
sns.despine();

# %%
sns.regplot(x="Thrust", y="Current (A)", data=data)
sns.despine();

# %%
sns.regplot(x="Thrust", y="Anode Flow (mg/s)", data=data)
sns.despine();

# %%
sns.regplot(x="Thrust", y="Cathode Flow (mg/s)", data=data)
sns.despine();

# %%
sns.regplot(x="Thrust", y="Cathode", data=data)
sns.despine();

# %%
sns.regplot(x="Thrust", y="Cathode Fraction", data=data)
sns.despine();

# %%
sns.regplot(x="Thrust", y="Specific impulse (s)", data=data)
sns.despine();

# %%
sns.regplot(x="Thrust", y="Efficiency", data=data)
sns.despine();
